# %% [markdown]
# Dataset Summary Report (Day 7)
# Create a Dataset Summary Report using Python and Pandas. Load the CSV dataset into a Pandas DataFrame and explore its basic structure and characteristics. Your notebook should demonstrate how to inspect the first and last few rows, view random samples, check the dataset’s shape, columns, index, and data types, and generate descriptive statistics using functions such as info() and describe(). Also include basic observations about the dataset, such as the number of rows and columns, available features, data types, and any noticeable missing values. Present the analysis clearly in a well-organized Colab Notebook. You can find the .csv file in the "Study material" tab in the LMS.

# %%
import pandas as pd

# 1. Load the dataset
df = pd.read_csv('Day7_Student_Dataset.csv')

# 2. Inspect basic structure
print("--- Dataset Shape ---")
print(df.shape)

print("\n--- First 5 Rows ---")
print(df.head())

print("\n--- Last 5 Rows ---")
print(df.tail())

print("\n--- Random Sample (3 Rows) ---")
print(df.sample(3))

print("\n--- DataFrame Info ---")
df.info()

print("\n--- Descriptive Statistics ---")
print(df.describe())

print("\n--- Missing Values Count ---")
print(df.isnull().sum())
